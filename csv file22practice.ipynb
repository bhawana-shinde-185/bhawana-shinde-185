# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\LENOVO\Downloads\file.csv')

# %%
data.head(10)
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
# 5  2011                    A  Agriculture, Forestry and Fishing          a_0
# 6  2011                    A  Agriculture, Forestry and Fishing          a_0
# 7  2011                    A  Agriculture, Forestry and Fishing          a_0
# 8  2011                    A  Agriculture, Forestry and Fishing          a_0
# 9  2011                    A  Agriculture, Forestry and Fishing        b_1-5
#
#                                           variable  value               unit
# ...

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df.dtypes()
#
# NameError: name 'df' is not defined

# %%
df= pd.DataFrame(data)

# %%
df.sort_values(by='year')
# Out:
#        year industry_code_ANZSIC  \
# 0      2011                    A
# 1037   2011                    M
# 1036   2011                    M
# 1035   2011                    M
# 1034   2011                    M
# ...     ...                  ...
# 15990  2021                    G
# 15989  2021                    G
# 15988  2021                    G
# 15962  2021                    F
# 17027  2021                  all
#
#                                   industry_name_ANZSIC      rme_size_grp  \
# 0                    Agriculture, Forestry and Fishing               a_0
# 1037   Professional, Scientific and Technical Services            h_200+
# 1036   Professional, Scientific and Technical Services            h_200+
# 1035   Professional, Scientific and Technical Services            h_200+
# 1034   Professional, Scientific and Technical Services         g_100-199
# ...                                                ...               ...
# ...

# %%
df.types()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df.types()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'types'

# %%
df.sort_values(by='year', ascending=False)
# Out:
#        year industry_code_ANZSIC  \
# 17027  2021                  all
# 15963  2021                    F
# 15989  2021                    G
# 15990  2021                    G
# 15991  2021                    G
# ...     ...                  ...
# 1035   2011                    M
# 1036   2011                    M
# 1037   2011                    M
# 1038   2011                    M
# 0      2011                    A
#
#                                   industry_name_ANZSIC      rme_size_grp  \
# 17027                                   All Industries     j_Grand_Total
# 15963                                  Wholesale Trade  i_Industry_Total
# 15989                                     Retail Trade             c_6-9
# 15990                                     Retail Trade             c_6-9
# 15991                                     Retail Trade             c_6-9
# ...                                                ...               ...
# ...

# %%
df.sort_values(by=['year', 'variable'], ascending=[False, True] )
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 15480  2021                    A  Agriculture, Forestry and Fishing
# 15489  2021                    A  Agriculture, Forestry and Fishing
# 15498  2021                    A  Agriculture, Forestry and Fishing
# 15507  2021                    A  Agriculture, Forestry and Fishing
# 15516  2021                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 1507   2011                    S                     Other Services
# 1516   2011                    S                     Other Services
# 1525   2011                    S                     Other Services
# 1534   2011                    S                     Other Services
# 1543   2011                  all                     All Industries
#
#            rme_size_grp       variable   value               unit
# 15480               a_0  Activity unit   41325              COUNT
# ...

# %%
df
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                  all                     All Industries
# 17024  2021                  all                     All Industries
# 17025  2021                  all                     All Industries
# 17026  2021                  all                     All Industries
# 17027  2021                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df.sort_index()
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                  all                     All Industries
# 17024  2021                  all                     All Industries
# 17025  2021                  all                     All Industries
# 17026  2021                  all                     All Industries
# 17027  2021                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df['industry_name_ANZSIC'].sort_values()
# Out:
# 9894     Accommodation and Food Services
# 5215     Accommodation and Food Services
# 5214     Accommodation and Food Services
# 5213     Accommodation and Food Services
# 5212     Accommodation and Food Services
#                       ...
# 5058                     Wholesale Trade
# 5059                     Wholesale Trade
# 5060                     Wholesale Trade
# 3577                     Wholesale Trade
# 12856                    Wholesale Trade
# Name: industry_name_ANZSIC, Length: 17028, dtype: object

# %%
df.sort_values(by=['industry_name_ANZSIC', 'variable'], ascending=[True, False], inplace=True)

# %%
df
# Out:
#        year industry_code_ANZSIC             industry_name_ANZSIC  \
# 571    2011                    H  Accommodation and Food Services
# 580    2011                    H  Accommodation and Food Services
# 589    2011                    H  Accommodation and Food Services
# 598    2011                    H  Accommodation and Food Services
# 607    2011                    H  Accommodation and Food Services
# ...     ...                  ...                              ...
# 15921  2021                    F                  Wholesale Trade
# 15930  2021                    F                  Wholesale Trade
# 15939  2021                    F                  Wholesale Trade
# 15948  2021                    F                  Wholesale Trade
# 15957  2021                    F                  Wholesale Trade
#
#            rme_size_grp       variable  value               unit
# 571                 a_0   Total income    807  DOLLARS(millions)
# ...

# %%
df['year'].nlargest(10)
# Out:
# 16051    2021
# 16060    2021
# 16069    2021
# 16078    2021
# 16087    2021
# 16096    2021
# 16105    2021
# 16114    2021
# 16123    2021
# 16052    2021
# Name: year, dtype: int64

# %%
df['year'].median()
# Out:
# 2016.0

# %%
df.nlargest(10, 'year')
# Out:
#        year industry_code_ANZSIC             industry_name_ANZSIC  \
# 16051  2021                    H  Accommodation and Food Services
# 16060  2021                    H  Accommodation and Food Services
# 16069  2021                    H  Accommodation and Food Services
# 16078  2021                    H  Accommodation and Food Services
# 16087  2021                    H  Accommodation and Food Services
# 16096  2021                    H  Accommodation and Food Services
# 16105  2021                    H  Accommodation and Food Services
# 16114  2021                    H  Accommodation and Food Services
# 16123  2021                    H  Accommodation and Food Services
# 16052  2021                    H  Accommodation and Food Services
#
#            rme_size_grp           variable  value               unit
# 16051               a_0       Total income   1296  DOLLARS(millions)
# 16060             b_1-5       Total income   2490  DOLLARS(millions)
# ...

# %%
df.nsmallest(10, 'year')
# Out:
#      year industry_code_ANZSIC             industry_name_ANZSIC  \
# 571  2011                    H  Accommodation and Food Services
# 580  2011                    H  Accommodation and Food Services
# 589  2011                    H  Accommodation and Food Services
# 598  2011                    H  Accommodation and Food Services
# 607  2011                    H  Accommodation and Food Services
# 616  2011                    H  Accommodation and Food Services
# 625  2011                    H  Accommodation and Food Services
# 634  2011                    H  Accommodation and Food Services
# 643  2011                    H  Accommodation and Food Services
# 572  2011                    H  Accommodation and Food Services
#
#          rme_size_grp           variable value               unit
# 571               a_0       Total income   807  DOLLARS(millions)
# 580             b_1-5       Total income  1708  DOLLARS(millions)
# ...

# %%
df.nlargest(10,'year')
# Out:
#        year industry_code_ANZSIC             industry_name_ANZSIC  \
# 16051  2021                    H  Accommodation and Food Services
# 16060  2021                    H  Accommodation and Food Services
# 16069  2021                    H  Accommodation and Food Services
# 16078  2021                    H  Accommodation and Food Services
# 16087  2021                    H  Accommodation and Food Services
# 16096  2021                    H  Accommodation and Food Services
# 16105  2021                    H  Accommodation and Food Services
# 16114  2021                    H  Accommodation and Food Services
# 16123  2021                    H  Accommodation and Food Services
# 16052  2021                    H  Accommodation and Food Services
#
#            rme_size_grp           variable  value               unit
# 16051               a_0       Total income   1296  DOLLARS(millions)
# 16060             b_1-5       Total income   2490  DOLLARS(millions)
# ...

# %%
df['year'].nlargest(10)
# Out:
# 16051    2021
# 16060    2021
# 16069    2021
# 16078    2021
# 16087    2021
# 16096    2021
# 16105    2021
# 16114    2021
# 16123    2021
# 16052    2021
# Name: year, dtype: int64

# %%
df.nlargest(10, 'year')
# Out:
#        year industry_code_ANZSIC             industry_name_ANZSIC  \
# 16051  2021                    H  Accommodation and Food Services
# 16060  2021                    H  Accommodation and Food Services
# 16069  2021                    H  Accommodation and Food Services
# 16078  2021                    H  Accommodation and Food Services
# 16087  2021                    H  Accommodation and Food Services
# 16096  2021                    H  Accommodation and Food Services
# 16105  2021                    H  Accommodation and Food Services
# 16114  2021                    H  Accommodation and Food Services
# 16123  2021                    H  Accommodation and Food Services
# 16052  2021                    H  Accommodation and Food Services
#
#            rme_size_grp           variable  value               unit
# 16051               a_0       Total income   1296  DOLLARS(millions)
# 16060             b_1-5       Total income   2490  DOLLARS(millions)
# ...

# %%
df.nsmallest(10,'year')
# Out:
#      year industry_code_ANZSIC             industry_name_ANZSIC  \
# 571  2011                    H  Accommodation and Food Services
# 580  2011                    H  Accommodation and Food Services
# 589  2011                    H  Accommodation and Food Services
# 598  2011                    H  Accommodation and Food Services
# 607  2011                    H  Accommodation and Food Services
# 616  2011                    H  Accommodation and Food Services
# 625  2011                    H  Accommodation and Food Services
# 634  2011                    H  Accommodation and Food Services
# 643  2011                    H  Accommodation and Food Services
# 572  2011                    H  Accommodation and Food Services
#
#          rme_size_grp           variable value               unit
# 571               a_0       Total income   807  DOLLARS(millions)
# 580             b_1-5       Total income  1708  DOLLARS(millions)
# ...

# %%
df.nsmallest(10, 'year')
# Out:
#      year industry_code_ANZSIC             industry_name_ANZSIC  \
# 571  2011                    H  Accommodation and Food Services
# 580  2011                    H  Accommodation and Food Services
# 589  2011                    H  Accommodation and Food Services
# 598  2011                    H  Accommodation and Food Services
# 607  2011                    H  Accommodation and Food Services
# 616  2011                    H  Accommodation and Food Services
# 625  2011                    H  Accommodation and Food Services
# 634  2011                    H  Accommodation and Food Services
# 643  2011                    H  Accommodation and Food Services
# 572  2011                    H  Accommodation and Food Services
#
#          rme_size_grp           variable value               unit
# 571               a_0       Total income   807  DOLLARS(millions)
# 580             b_1-5       Total income  1708  DOLLARS(millions)
# ...

# %%
df['year'].nsmallest(10)
# Out:
# 571    2011
# 580    2011
# 589    2011
# 598    2011
# 607    2011
# 616    2011
# 625    2011
# 634    2011
# 643    2011
# 572    2011
# Name: year, dtype: int64

# %%
df['year'].nlargest(10)
# Out:
# 16051    2021
# 16060    2021
# 16069    2021
# 16078    2021
# 16087    2021
# 16096    2021
# 16105    2021
# 16114    2021
# 16123    2021
# 16052    2021
# Name: year, dtype: int64

# %%
df['year'].nlargest(10)
# Out:
# 16051    2021
# 16060    2021
# 16069    2021
# 16078    2021
# 16087    2021
# 16096    2021
# 16105    2021
# 16114    2021
# 16123    2021
# 16052    2021
# Name: year, dtype: int64

# %%
country_grp = df.groupby(['year'])

# %%
type(country_grp)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df.sort_values(by='variable', ascending=False, inplace=True)

# %%
df
# Out:
#        year industry_code_ANZSIC                        industry_name_ANZSIC  \
# 571    2011                    H             Accommodation and Food Services
# 12496  2019                    B                                      Mining
# 10975  2018                    B                                      Mining
# 10984  2018                    B                                      Mining
# 10993  2018                    B                                      Mining
# ...     ...                  ...                                         ...
# 12636  2019                    D  Electricity, Gas, Water and Waste Services
# 12645  2019                    D  Electricity, Gas, Water and Waste Services
# 12654  2019                    D  Electricity, Gas, Water and Waste Services
# 12663  2019                    D  Electricity, Gas, Water and Waste Services
# 15957  2021                    F                             Wholesale Trade
#
# ...

# %%
df.dropna(axis='index', how='all', subset=['variable','value'])
# Out:
#        year industry_code_ANZSIC                 industry_name_ANZSIC  \
# 571    2011                    H      Accommodation and Food Services
# 6837   2015                    H      Accommodation and Food Services
# 1666   2012                    B                               Mining
# 13483  2019                    N  Administrative and Support Services
# 15004  2020                    N  Administrative and Support Services
# ...     ...                  ...                                  ...
# 7311   2015                    N  Administrative and Support Services
# 7302   2015                    N  Administrative and Support Services
# 5736   2014                    N  Administrative and Support Services
# 16041  2021                    G                         Retail Trade
# 15957  2021                    F                      Wholesale Trade
#
#            rme_size_grp                                           variable  \
# ...

# %%
d='10:23:34 PM'
pd.to_datetime(d).strftime('%H:%M:%S')
# Out:
# '22:23:34'

# %%
df.dropna()
# Out:
#        year industry_code_ANZSIC                 industry_name_ANZSIC  \
# 571    2011                    H      Accommodation and Food Services
# 6837   2015                    H      Accommodation and Food Services
# 1666   2012                    B                               Mining
# 13483  2019                    N  Administrative and Support Services
# 15004  2020                    N  Administrative and Support Services
# ...     ...                  ...                                  ...
# 7311   2015                    N  Administrative and Support Services
# 7302   2015                    N  Administrative and Support Services
# 5736   2014                    N  Administrative and Support Services
# 16041  2021                    G                         Retail Trade
# 15957  2021                    F                      Wholesale Trade
#
#            rme_size_grp                                           variable  \
# ...

# %%
df.dropna(axis='index', how='all', subset=['variable','value'])
# Out:
#        year industry_code_ANZSIC                        industry_name_ANZSIC  \
# 571    2011                    H             Accommodation and Food Services
# 12496  2019                    B                                      Mining
# 10975  2018                    B                                      Mining
# 10984  2018                    B                                      Mining
# 10993  2018                    B                                      Mining
# ...     ...                  ...                                         ...
# 12636  2019                    D  Electricity, Gas, Water and Waste Services
# 12645  2019                    D  Electricity, Gas, Water and Waste Services
# 12654  2019                    D  Electricity, Gas, Water and Waste Services
# 12663  2019                    D  Electricity, Gas, Water and Waste Services
# 15957  2021                    F                             Wholesale Trade
#
# ...

# %%
df.isna()
# Out:
#         year  industry_code_ANZSIC  industry_name_ANZSIC  rme_size_grp  \
# 571    False                 False                 False         False
# 12496  False                 False                 False         False
# 10975  False                 False                 False         False
# 10984  False                 False                 False         False
# 10993  False                 False                 False         False
# ...      ...                   ...                   ...           ...
# 12636  False                 False                 False         False
# 12645  False                 False                 False         False
# 12654  False                 False                 False         False
# 12663  False                 False                 False         False
# 15957  False                 False                 False         False
#
#        variable  value   unit
# 571       False  False  False
# 12496     False  False  False
# ...

# %%
df.fillna('MISSING')
# Out:
#        year industry_code_ANZSIC                        industry_name_ANZSIC  \
# 571    2011                    H             Accommodation and Food Services
# 12496  2019                    B                                      Mining
# 10975  2018                    B                                      Mining
# 10984  2018                    B                                      Mining
# 10993  2018                    B                                      Mining
# ...     ...                  ...                                         ...
# 12636  2019                    D  Electricity, Gas, Water and Waste Services
# 12645  2019                    D  Electricity, Gas, Water and Waste Services
# 12654  2019                    D  Electricity, Gas, Water and Waste Services
# 12663  2019                    D  Electricity, Gas, Water and Waste Services
# 15957  2021                    F                             Wholesale Trade
#
# ...

# %%
df.dtypes
# Out:
# year                     int64
# industry_code_ANZSIC    object
# industry_name_ANZSIC    object
# rme_size_grp            object
# variable                object
# value                   object
# unit                    object
# dtype: object

# %%
na_vals = ['NA', 'Missing']

# %%
df['variable'].replace('Less than 1 ', 0, inplace=True)

# %%
df['year'].unique()
# Out:
# array([2011, 2015, 2012, 2019, 2020, 2016, 2017, 2014, 2013, 2021, 2018],
#       dtype=int64)

# %%
df['year'].mean()
# Out:
# 2016.0

# %%
df['year'].median()
# Out:
# 2016.0

# %%
df['variable']=['variable'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [95], in <cell line: 1>()
# ----> 1 df['variable']=['variable'].astype(str)
#
# AttributeError: 'list' object has no attribute 'astype'
