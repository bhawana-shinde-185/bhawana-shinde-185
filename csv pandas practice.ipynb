# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\LENOVO\Downloads\file.csv')

# %%
data
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                  all                     All Industries
# 17024  2021                  all                     All Industries
# 17025  2021                  all                     All Industries
# 17026  2021                  all                     All Industries
# 17027  2021                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df['variable'].str.split(' ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df['variable'].str.split(' ')
#
# NameError: name 'df' is not defined

# %%
data.head()
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17028 entries, 0 to 17027
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  17028 non-null  int64
#  1   industry_code_ANZSIC  17028 non-null  object
#  2   industry_name_ANZSIC  17028 non-null  object
#  3   rme_size_grp          17028 non-null  object
#  4   variable              17028 non-null  object
#  5   value                 17028 non-null  object
#  6   unit                  17028 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 931.3+ KB

# %%
data.shape
# Out:
# (17028, 7)

# %%
data.head()
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                  all                     All Industries
# 17024  2021                  all                     All Industries
# 17025  2021                  all                     All Industries
# 17026  2021                  all                     All Industries
# 17027  2021                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['value'])
# Out:
# pandas.core.series.Series

# %%
type(df['unit'])
# Out:
# pandas.core.series.Series

# %%
df.loc[1,"year"]
# Out:
# 2011

# %%
df.iloc[0]
# Out:
# year                                                 2011
# industry_code_ANZSIC                                    A
# industry_name_ANZSIC    Agriculture, Forestry and Fishing
# rme_size_grp                                          a_0
# variable                                    Activity unit
# value                                               46134
# unit                                                COUNT
# Name: 0, dtype: object

# %%
df.iloc[3]
# Out:
# year                                                               2011
# industry_code_ANZSIC                                                  A
# industry_name_ANZSIC                  Agriculture, Forestry and Fishing
# rme_size_grp                                                        a_0
# variable                Sales, government funding, grants and subsidies
# value                                                              8187
# unit                                                  DOLLARS(millions)
# Name: 3, dtype: object

# %%
df.iloc[17023]
# Out:
# year                                 2021
# industry_code_ANZSIC                  all
# industry_name_ANZSIC       All Industries
# rme_size_grp                j_Grand_Total
# variable                     Total income
# value                              757504
# unit                    DOLLARS(millions)
# Name: 17023, dtype: object

# %%
df.loc[[0, 1]]
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                  variable  value   unit
# 0           Activity unit  46134  COUNT
# 1  Rolling mean employees      0  COUNT

# %%
df.loc[[0,1,2,3]]
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)

# %%
df.loc[[0, 1,3,4,5], 'variable']
# Out:
# 0                                      Activity unit
# 1                             Rolling mean employees
# 3    Sales, government funding, grants and subsidies
# 4                                       Total income
# 5                                  Total expenditure
# Name: variable, dtype: object

# %%
df.loc[[0,1,2],'value']
# Out:
# 0    46134
# 1        0
# 2      279
# Name: value, dtype: object

# %%
df.loc[[0, 1,2],["variable",'value']]
# Out:
#                   variable  value
# 0            Activity unit  46134
# 1   Rolling mean employees      0
# 2  Salaries and wages paid    279

# %%
df.loc[[0, 1, 2], 'unit']
# Out:
# 0                COUNT
# 1                COUNT
# 2    DOLLARS(millions)
# Name: unit, dtype: object

# %%
df['variable'].value_counts()
# Out:
# Activity unit                                      1892
# Rolling mean employees                             1892
# Salaries and wages paid                            1892
# Sales, government funding, grants and subsidies    1892
# Total income                                       1892
# Total expenditure                                  1892
# Operating profit before tax                        1892
# Total assets                                       1892
# Fixed tangible assets                              1892
# Name: variable, dtype: int64

# %%
df.loc[0]
# Out:
# year                                                 2011
# industry_code_ANZSIC                                    A
# industry_name_ANZSIC    Agriculture, Forestry and Fishing
# rme_size_grp                                          a_0
# variable                                    Activity unit
# value                                               46134
# unit                                                COUNT
# Name: 0, dtype: object

# %%
df.loc[2:3]
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable value               unit
# 2                          Salaries and wages paid   279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies  8187  DOLLARS(millions)

# %%
df.loc[4:5]
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
# 5  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#             variable value               unit
# 4       Total income  8866  DOLLARS(millions)
# 5  Total expenditure  7618  DOLLARS(millions)

# %%
df.loc[0:2, 'variable':'value']
# Out:
#                   variable  value
# 0            Activity unit  46134
# 1   Rolling mean employees      0
# 2  Salaries and wages paid    279

# %%
data.columns
# Out:
# Index(['year', 'industry_code_ANZSIC', 'industry_name_ANZSIC', 'rme_size_grp',
#        'variable', 'value', 'unit'],
#       dtype='object')

# %%
data['variable']
# Out:
# 0                                          Activity unit
# 1                                 Rolling mean employees
# 2                                Salaries and wages paid
# 3        Sales, government funding, grants and subsidies
# 4                                           Total income
#                               ...
# 17023                                       Total income
# 17024                                  Total expenditure
# 17025                        Operating profit before tax
# 17026                                       Total assets
# 17027                              Fixed tangible assets
# Name: variable, Length: 17028, dtype: object

# %%
df['variable'].value_counts()
# Out:
# Activity unit                                      1892
# Rolling mean employees                             1892
# Salaries and wages paid                            1892
# Sales, government funding, grants and subsidies    1892
# Total income                                       1892
# Total expenditure                                  1892
# Operating profit before tax                        1892
# Total assets                                       1892
# Fixed tangible assets                              1892
# Name: variable, dtype: int64

# %%
df["industry_name_ANZSIC"].value_counts()
# Out:
# Agriculture, Forestry and Fishing                  891
# Mining                                             891
# Other Services                                     891
# Arts and Recreation Services                       891
# Health Care and Social Assistance                  891
# Education and Training                             891
# Public Administration and Safety                   891
# Administrative and Support Services                891
# Professional, Scientific and Technical Services    891
# Rental, Hiring and Real Estate Services            891
# Financial and Insurance Services                   891
# Information Media and Telecommunications           891
# Transport, Postal and Warehousing                  891
# Accommodation and Food Services                    891
# Retail Trade                                       891
# Wholesale Trade                                    891
# Construction                                       891
# ...

# %%
data.loc[[0, 1, 2], 'variable']
# Out:
# 0              Activity unit
# 1     Rolling mean employees
# 2    Salaries and wages paid
# Name: variable, dtype: object

# %%
data.loc[0:5]
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
# 5  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# ...

# %%
data.loc[0:10]
# Out:
#     year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0   2011                    A  Agriculture, Forestry and Fishing          a_0
# 1   2011                    A  Agriculture, Forestry and Fishing          a_0
# 2   2011                    A  Agriculture, Forestry and Fishing          a_0
# 3   2011                    A  Agriculture, Forestry and Fishing          a_0
# 4   2011                    A  Agriculture, Forestry and Fishing          a_0
# 5   2011                    A  Agriculture, Forestry and Fishing          a_0
# 6   2011                    A  Agriculture, Forestry and Fishing          a_0
# 7   2011                    A  Agriculture, Forestry and Fishing          a_0
# 8   2011                    A  Agriculture, Forestry and Fishing          a_0
# 9   2011                    A  Agriculture, Forestry and Fishing        b_1-5
# 10  2011                    A  Agriculture, Forestry and Fishing        b_1-5
#
# ...

# %%
data.loc[5, 'rme_size_grp']
# Out:
# 'a_0'

# %%
data.loc[0:2, 'variable':'value']
# Out:
#                   variable  value
# 0            Activity unit  46134
# 1   Rolling mean employees      0
# 2  Salaries and wages paid    279

# %%
df.iloc[[0, 1], 2]
# Out:
# 0    Agriculture, Forestry and Fishing
# 1    Agriculture, Forestry and Fishing
# Name: industry_name_ANZSIC, dtype: object

# %%
df.set_index('value')
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# value
# 46134    2011                    A  Agriculture, Forestry and Fishing
# 0        2011                    A  Agriculture, Forestry and Fishing
# 279      2011                    A  Agriculture, Forestry and Fishing
# 8187     2011                    A  Agriculture, Forestry and Fishing
# 8866     2011                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 757504   2021                  all                     All Industries
# 654404   2021                  all                     All Industries
# 85116    2021                  all                     All Industries
# 2512677  2021                  all                     All Industries
# 591351   2021                  all                     All Industries
#
#           rme_size_grp                                         variable  \
# value
# ...

# %%
df.set_index('value',inplace=True)

# %%
df
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# value
# 46134    2011                    A  Agriculture, Forestry and Fishing
# 0        2011                    A  Agriculture, Forestry and Fishing
# 279      2011                    A  Agriculture, Forestry and Fishing
# 8187     2011                    A  Agriculture, Forestry and Fishing
# 8866     2011                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 757504   2021                  all                     All Industries
# 654404   2021                  all                     All Industries
# 85116    2021                  all                     All Industries
# 2512677  2021                  all                     All Industries
# 591351   2021                  all                     All Industries
#
#           rme_size_grp                                         variable  \
# value
# ...

# %%
df.index
# Out:
# Index(['46134', '0', '279', '8187', '8866', '7618', '770', '55700', '32155',
#        '21777',
#        ...
#        '4407', '500568', '1889430', '123620', '674890', '757504', '654404',
#        '85116', '2512677', '591351'],
#       dtype='object', name='value', length=17028)

# %%
df.loc['46134']
# Out:
# year                                                 2011
# industry_code_ANZSIC                                    A
# industry_name_ANZSIC    Agriculture, Forestry and Fishing
# rme_size_grp                                          a_0
# variable                                    Activity unit
# unit                                                COUNT
# Name: 46134, dtype: object

# %%
df.loc[2, 'last'] = 'variable'

# %%
df
# Out:
#            year industry_code_ANZSIC               industry_name_ANZSIC  \
# value
# 46134    2011.0                    A  Agriculture, Forestry and Fishing
# 0        2011.0                    A  Agriculture, Forestry and Fishing
# 279      2011.0                    A  Agriculture, Forestry and Fishing
# 8187     2011.0                    A  Agriculture, Forestry and Fishing
# 8866     2011.0                    A  Agriculture, Forestry and Fishing
# ...         ...                  ...                                ...
# 654404   2021.0                  all                     All Industries
# 85116    2021.0                  all                     All Industries
# 2512677  2021.0                  all                     All Industries
# 591351   2021.0                  all                     All Industries
# 2           NaN                  NaN                                NaN
#
#           rme_size_grp                                         variable  \
# value
# ...

# %%
df.at[2, 'last'] = 'value'

# %%
df
# Out:
#            year industry_code_ANZSIC               industry_name_ANZSIC  \
# value
# 46134    2011.0                    A  Agriculture, Forestry and Fishing
# 0        2011.0                    A  Agriculture, Forestry and Fishing
# 279      2011.0                    A  Agriculture, Forestry and Fishing
# 8187     2011.0                    A  Agriculture, Forestry and Fishing
# 8866     2011.0                    A  Agriculture, Forestry and Fishing
# ...         ...                  ...                                ...
# 654404   2021.0                  all                     All Industries
# 85116    2021.0                  all                     All Industries
# 2512677  2021.0                  all                     All Industries
# 591351   2021.0                  all                     All Industries
# 2           NaN                  NaN                                NaN
#
#           rme_size_grp                                         variable  \
# value
# ...

# %%
filt = (df['last'] == 'year')
df[filt]
# Out:
# Empty DataFrame
# Columns: [year, industry_code_ANZSIC, industry_name_ANZSIC, rme_size_grp, variable, unit, last]
# Index: []

# %%
filt = (df['variable'] == 'industry_name_ANZSIC')
df[filt]['industry_name_ANZSIC']
# Out:
# Series([], Name: industry_name_ANZSIC, dtype: object)

# %%
df['variable'].str.upper()
# Out:
# value
# 46134                                        ACTIVITY UNIT
# 0                                   ROLLING MEAN EMPLOYEES
# 279                                SALARIES AND WAGES PAID
# 8187       SALES, GOVERNMENT FUNDING, GRANTS AND SUBSIDIES
# 8866                                          TOTAL INCOME
#                                 ...
# 654404                                   TOTAL EXPENDITURE
# 85116                          OPERATING PROFIT BEFORE TAX
# 2512677                                       TOTAL ASSETS
# 591351                               FIXED TANGIBLE ASSETS
# 2                                                      NaN
# Name: variable, Length: 17029, dtype: object

# %%
df.apply(len)
# Out:
# year                    17029
# industry_code_ANZSIC    17029
# industry_name_ANZSIC    17029
# rme_size_grp            17029
# variable                17029
# unit                    17029
# last                    17029
# dtype: int64

# %%
len(df['variable'])
# Out:
# 17029

# %%
df.apply(len,axis='columns')
# Out:
# value
# 46134      7
# 0          7
# 279        7
# 8187       7
# 8866       7
#           ..
# 654404     7
# 85116      7
# 2512677    7
# 591351     7
# 2          7
# Length: 17029, dtype: int64

# %%
df.apply(len, axis='columns')
# Out:
# value
# 46134      7
# 0          7
# 279        7
# 8187       7
# 8866       7
#           ..
# 654404     7
# 85116      7
# 2512677    7
# 591351     7
# 2          7
# Length: 17029, dtype: int64

# %%
df.apply(len,axis= 'rows')
# Out:
# year                    17029
# industry_code_ANZSIC    17029
# industry_name_ANZSIC    17029
# rme_size_grp            17029
# variable                17029
# unit                    17029
# last                    17029
# dtype: int64

# %%
df.applymap(lambda x: x.min('variable'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 df.applymap(lambda x: x.min('variable'))
#
# NameError: name 'df' is not defined

# %%
df.apply(lambda x:x.min())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [436], in <cell line: 1>()
# ----> 1 df.apply(lambda x:x.min())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8845, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8834 from pandas.core.apply import frame_apply
#    8836 op = frame_apply(
#    8837     self,
#    8838     func=func,
#    (...)
#    8843     kwargs=kwargs,
#    8844 )
# -> 8845 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:733, in FrameApply.apply(self)
#     730 elif self.raw:
#     731     return self.apply_raw()
# --> 733 return self.apply_standard()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:857, in FrameApply.apply_standard(self)
# ...

# %%
df.apply(lambda x: x.min('value'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'value'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [437], in <cell line: 1>()
# ----> 1 df.apply(lambda x: x.min('value'))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8845, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8834 from pandas.core.apply import frame_apply
#    8836 op = frame_apply(
#    8837     self,
#    8838     func=func,
#    (...)
#    8843     kwargs=kwargs,
#    8844 )
# ...

# %%
df.applymap(len('variable'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [438], in <cell line: 1>()
# ----> 1 df.applymap(len('variable'))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8922, in DataFrame.applymap(self, func, na_action, **kwargs)
#    8918     raise ValueError(
#    8919         f"na_action must be 'ignore' or None. Got {repr(na_action)}"
#    8920     )
#    8921 ignore_na = na_action == "ignore"
# -> 8922 func = functools.partial(func, **kwargs)
#    8924 # if we have a dtype == 'M8[ns]', provide boxed values
#    8925 def infer(x):
#
# TypeError: the first argument must be callable

# %%
df.applymap(str.lower)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [439], in <cell line: 1>()
# ----> 1 df.applymap(str.lower)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8930, in DataFrame.applymap(self, func, na_action, **kwargs)
#    8927         return lib.map_infer(x, func, ignore_na=ignore_na)
#    8928     return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
# -> 8930 return self.apply(infer).__finalize__(self, "applymap")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8845, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8834 from pandas.core.apply import frame_apply
#    8836 op = frame_apply(
#    8837     self,
#    8838     func=func,
#    (...)
#    8843     kwargs=kwargs,
#    8844 )
# ...

# %%
df.replace({'year22': 'year', 'variable22': 'variable'})
# Out:
#            year industry_code_ANZSIC               industry_name_ANZSIC  \
# value
# 46134    2011.0                    A  Agriculture, Forestry and Fishing
# 0        2011.0                    A  Agriculture, Forestry and Fishing
# 279      2011.0                    A  Agriculture, Forestry and Fishing
# 8187     2011.0                    A  Agriculture, Forestry and Fishing
# 8866     2011.0                    A  Agriculture, Forestry and Fishing
# ...         ...                  ...                                ...
# 654404   2021.0                  all                     All Industries
# 85116    2021.0                  all                     All Industries
# 2512677  2021.0                  all                     All Industries
# 591351   2021.0                  all                     All Industries
# 2           NaN                  NaN                                NaN
#
#           rme_size_grp                                         variable  \
# value
# ...

# %%
df.rename(columns={'industry_name_ANZSIC': 'variable'}).head(1)
# Out:
#          year industry_code_ANZSIC                           variable  \
# value
# 46134  2011.0                    A  Agriculture, Forestry and Fishing
#
#       rme_size_grp       variable   unit last
# value
# 46134          a_0  Activity unit  COUNT  NaN

# %%
df.rename(columns={'industry_name_ANZSIC':'variable'}).head(10)
# Out:
#          year industry_code_ANZSIC                           variable  \
# value
# 46134  2011.0                    A  Agriculture, Forestry and Fishing
# 0      2011.0                    A  Agriculture, Forestry and Fishing
# 279    2011.0                    A  Agriculture, Forestry and Fishing
# 8187   2011.0                    A  Agriculture, Forestry and Fishing
# 8866   2011.0                    A  Agriculture, Forestry and Fishing
# 7618   2011.0                    A  Agriculture, Forestry and Fishing
# 770    2011.0                    A  Agriculture, Forestry and Fishing
# 55700  2011.0                    A  Agriculture, Forestry and Fishing
# 32155  2011.0                    A  Agriculture, Forestry and Fishing
# 21777  2011.0                    A  Agriculture, Forestry and Fishing
#
#       rme_size_grp                                         variable  \
# value
# 46134          a_0                                    Activity unit
# ...

# %%
df['variable22'].map({'Yes': True, 'No': False})
# Out:
# value
# 46134      NaN
# 0          NaN
# 279        NaN
# 8187       NaN
# 8866       NaN
#           ...
# 654404     NaN
# 85116      NaN
# 2512677    NaN
# 591351     NaN
# 2          NaN
# Name: variable22, Length: 17029, dtype: object

# %%
df
# Out:
#          year22 industry code ANZSIC               industry name ANZSIC  \
# value
# 46134    2011.0                    A  Agriculture, Forestry and Fishing
# 0        2011.0                    A  Agriculture, Forestry and Fishing
# 279      2011.0                    A  Agriculture, Forestry and Fishing
# 8187     2011.0                    A  Agriculture, Forestry and Fishing
# 8866     2011.0                    A  Agriculture, Forestry and Fishing
# ...         ...                  ...                                ...
# 654404   2021.0                  all                     All Industries
# 85116    2021.0                  all                     All Industries
# 2512677  2021.0                  all                     All Industries
# 591351   2021.0                  all                     All Industries
# 2           NaN                  NaN                                NaN
#
#         rme size grp                                       variable22  \
# value
# ...

# %%
df
# Out:
#          year22 industry code ANZSIC               industry name ANZSIC  \
# value
# 46134    2011.0                    A  Agriculture, Forestry and Fishing
# 0        2011.0                    A  Agriculture, Forestry and Fishing
# 279      2011.0                    A  Agriculture, Forestry and Fishing
# 8187     2011.0                    A  Agriculture, Forestry and Fishing
# 8866     2011.0                    A  Agriculture, Forestry and Fishing
# ...         ...                  ...                                ...
# 654404   2021.0                  all                     All Industries
# 85116    2021.0                  all                     All Industries
# 2512677  2021.0                  all                     All Industries
# 591351   2021.0                  all                     All Industries
# 2           NaN                  NaN                                NaN
#
#         rme size grp                                       variable22  \
# value
# ...

# %%
get_columns = [i for i in df.columns]

# %%
get_columns = list(map(lambda x : x.replace("_"," "),get_columns))

# %%
get_columns

# %%
df.columns = get_columns

# %%
df['rme_size_grp'] + ' ' + df['variable']
# Out:
# value
# 46134      NaN
# 0          NaN
# 279        NaN
# 8187       NaN
# 8866       NaN
#           ...
# 654404     NaN
# 85116      NaN
# 2512677    NaN
# 591351     NaN
# 2          NaN
# Length: 17029, dtype: object

# %%
df.rename(columns={'year': 'year22', 'variable': 'variable22'},inplace=True)

# %%
df
# Out:
#          year22 industry code ANZSIC               industry name ANZSIC  \
# value
# 46134    2011.0                    A  Agriculture, Forestry and Fishing
# 0        2011.0                    A  Agriculture, Forestry and Fishing
# 279      2011.0                    A  Agriculture, Forestry and Fishing
# 8187     2011.0                    A  Agriculture, Forestry and Fishing
# 8866     2011.0                    A  Agriculture, Forestry and Fishing
# ...         ...                  ...                                ...
# 654404   2021.0                  all                     All Industries
# 85116    2021.0                  all                     All Industries
# 2512677  2021.0                  all                     All Industries
# 591351   2021.0                  all                     All Industries
# 2           NaN                  NaN                                NaN
#
#         rme size grp                                       variable22  \
# value
# ...

# %%
df.drop(columns=['year22', 'variable22'])
# Out:
#         industry code ANZSIC               industry name ANZSIC rme size grp  \
# value
# 46134                      A  Agriculture, Forestry and Fishing          NaN
# 0                          A  Agriculture, Forestry and Fishing          NaN
# 279                        A  Agriculture, Forestry and Fishing          NaN
# 8187                       A  Agriculture, Forestry and Fishing          NaN
# 8866                       A  Agriculture, Forestry and Fishing          NaN
# ...                      ...                                ...          ...
# 654404                   all                     All Industries          NaN
# 85116                    all                     All Industries          NaN
# 2512677                  all                     All Industries          NaN
# 591351                   all                     All Industries          NaN
# 2                        NaN                                NaN          NaN
#
#                       unit   last
# ...

# %%
df.drop(columns=['year22', 'variable22'], inplace=True)

# %%
df
# Out:
#         industry code ANZSIC               industry name ANZSIC rme size grp  \
# value
# 46134                      A  Agriculture, Forestry and Fishing          NaN
# 0                          A  Agriculture, Forestry and Fishing          NaN
# 279                        A  Agriculture, Forestry and Fishing          NaN
# 8187                       A  Agriculture, Forestry and Fishing          NaN
# 8866                       A  Agriculture, Forestry and Fishing          NaN
# ...                      ...                                ...          ...
# 654404                   all                     All Industries          NaN
# 85116                    all                     All Industries          NaN
# 2512677                  all                     All Industries          NaN
# 591351                   all                     All Industries          NaN
# 2                        NaN                                NaN          NaN
#
#                       unit   last
# ...

# %%
df['industry code ANZSIC'].str.split(' ')
# Out:
# value
# 46134        [A]
# 0            [A]
# 279          [A]
# 8187         [A]
# 8866         [A]
#            ...
# 654404     [all]
# 85116      [all]
# 2512677    [all]
# 591351     [all]
# 2            NaN
# Name: industry code ANZSIC, Length: 17029, dtype: object

# %%
df['industry code ANZSIC'].str.split(' ', expand=True)
# Out:
#            0
# value
# 46134      A
# 0          A
# 279        A
# 8187       A
# 8866       A
# ...      ...
# 654404   all
# 85116    all
# 2512677  all
# 591351   all
# 2        NaN
#
# [17029 rows x 1 columns]

# %%
df= df['industry name ANZSIC'].str.split(' ', expand=True)

# %%
df
# Out:
#                     0           1     2        3     4     5
# value
# 46134    Agriculture,    Forestry   and  Fishing  None  None
# 0        Agriculture,    Forestry   and  Fishing  None  None
# 279      Agriculture,    Forestry   and  Fishing  None  None
# 8187     Agriculture,    Forestry   and  Fishing  None  None
# 8866     Agriculture,    Forestry   and  Fishing  None  None
# ...               ...         ...   ...      ...   ...   ...
# 654404            All  Industries  None     None  None  None
# 85116             All  Industries  None     None  None  None
# 2512677           All  Industries  None     None  None  None
# 591351            All  Industries  None     None  None  None
# 2                 NaN         NaN   NaN      NaN   NaN   NaN
#
# [17029 rows x 6 columns]

# %%
df.append({'industry name ANZSIC': 'abc'}, ignore_index=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8316\994683561.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'industry name ANZSIC': 'abc'}, ignore_index=True)
#                   0           1     2        3     4     5  \
# 0      Agriculture,    Forestry   and  Fishing  None  None
# 1      Agriculture,    Forestry   and  Fishing  None  None
# 2      Agriculture,    Forestry   and  Fishing  None  None
# 3      Agriculture,    Forestry   and  Fishing  None  None
# 4      Agriculture,    Forestry   and  Fishing  None  None
# ...             ...         ...   ...      ...   ...   ...
# 17025           All  Industries  None     None  None  None
# 17026           All  Industries  None     None  None  None
# 17027           All  Industries  None     None  None  None
# 17028           NaN         NaN   NaN      NaN   NaN   NaN
# ...

# %%
df.drop(index=2)
# Out:
#                     0           1     2        3     4     5
# value
# 46134    Agriculture,    Forestry   and  Fishing  None  None
# 0        Agriculture,    Forestry   and  Fishing  None  None
# 279      Agriculture,    Forestry   and  Fishing  None  None
# 8187     Agriculture,    Forestry   and  Fishing  None  None
# 8866     Agriculture,    Forestry   and  Fishing  None  None
# ...               ...         ...   ...      ...   ...   ...
# 757504            All  Industries  None     None  None  None
# 654404            All  Industries  None     None  None  None
# 85116             All  Industries  None     None  None  None
# 2512677           All  Industries  None     None  None  None
# 591351            All  Industries  None     None  None  None
#
# [17028 rows x 6 columns]

# %%
filt = df['industry name ANZSIC'] == 'Doe'
df.drop(index=df[filt].index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [540], in <cell line: 1>()
# ----> 1 filt = df['industry name ANZSIC'] == 'Doe'
#       2 df.drop(index=df[filt].index)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\range.py:389, in RangeIndex.get_loc(self, key, method, tolerance)
#     387             raise KeyError(key) from err
#     388     self._check_indexing_error(key)
# --> 389     raise KeyError(key)
#     390 return super().get_loc(key, method=method, tolerance=tolerance)
#
# ...

# %%
df.sort_values(by='industry name ANZSIC')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [542], in <cell line: 1>()
# ----> 1 df.sort_values(by='industry name ANZSIC')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:6319, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6315 elif len(by):
#    6316     # len(by) == 1
#    6318     by = by[0]
# ...

# %%
df
# Out:
#                     0           1     2        3     4     5
# value
# 46134    Agriculture,    Forestry   and  Fishing  None  None
# 0        Agriculture,    Forestry   and  Fishing  None  None
# 279      Agriculture,    Forestry   and  Fishing  None  None
# 8187     Agriculture,    Forestry   and  Fishing  None  None
# 8866     Agriculture,    Forestry   and  Fishing  None  None
# ...               ...         ...   ...      ...   ...   ...
# 654404            All  Industries  None     None  None  None
# 85116             All  Industries  None     None  None  None
# 2512677           All  Industries  None     None  None  None
# 591351            All  Industries  None     None  None  None
# 2                 NaN         NaN   NaN      NaN   NaN   NaN
#
# [17029 rows x 6 columns]
